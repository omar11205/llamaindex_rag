# %%
"""
At the command line, only need to run once to install the package via pip:

$ pip install google-generativeai
"""

import google.generativeai as genai
import os

genai.configure(api_key=os.environ['GOOGLEAI_API_KEY'])

# Set up the model
generation_config = {
  "temperature": 0.9,
  "top_p": 1,
  "top_k": 1,
  "max_output_tokens": 2048,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
]

model = genai.GenerativeModel(model_name="gemini-1.0-pro",
                              generation_config=generation_config,
                              safety_settings=safety_settings)

convo = model.start_chat(history=[
  {
    "role": "user",
    "parts": ["give a code in python to demonstrate the use of the fermat last theorem"]
  },
  {
    "role": "model",
    "parts": ["```python\ndef fermat_last_theorem(a, b, c, n):\n  \"\"\"\n  Checks if Fermat's Last Theorem holds for the given input.\n\n  Args:\n    a: A positive integer.\n    b: A positive integer.\n    c: A positive integer.\n    n: A positive integer greater than 2.\n\n  Returns:\n    True if Fermat's Last Theorem holds for the given input, False otherwise.\n  \"\"\"\n\n  # Check if a^n + b^n = c^n.\n  if a**n + b**n == c**n:\n    return False\n\n  # Otherwise, Fermat's Last Theorem holds for the given input.\n  return True\n\n\nif __name__ == \"__main__\":\n  # Get the input from the user.\n  a = int(input(\"Enter a: \"))\n  b = int(input(\"Enter b: \"))\n  c = int(input(\"Enter c: \"))\n  n = int(input(\"Enter n: \"))\n\n  # Check if Fermat's Last Theorem holds for the given input.\n  result = fermat_last_theorem(a, b, c, n)\n\n  # Print the result.\n  if result:\n    print(\"Fermat's Last Theorem holds for the given input.\")\n  else:\n    print(\"Fermat's Last Theorem does not hold for the given input.\")\n```"]
  },
])

convo.send_message("YOUR_USER_INPUT")
print(convo.last.text)
# Out:
# ```python
# def is_prime(n):
#   """
#   Checks if n is a prime number.
#
#   Args:
#     n: A positive integer.
#
#   Returns:
#     True if n is prime, False otherwise.
#   """
#
#   # If n is 1, it is not prime.
#   if n == 1:
#     return False
#
#   # Iterate over all integers from 2 to the square root of n.
#   for i in range(2, int(n**0.5) + 1):
#     # If n is divisible by any integer from 2 to its square root, it is not prime.
#     if n % i == 0:
#       return False
#
#   # Otherwise, n is prime.
#   return True
#
#
# def is_perfect_square(n):
#   """
#   Checks if n is a perfect square.
#
#   Args:
#     n: A positive integer.
#
#   Returns:
#     True if n is a perfect square, False otherwise.
#   """
#
#   # Check if the square root of n is an integer.
#   return int(n**0.5)**2 == n
#
#
# def pythagorean_triple(a, b, c):
#   """
#   Checks if (a, b, c) is a Pythagorean triple.
#
#   Args:
#     a: A positive integer.
#     b: A positive integer.
#     c: A positive integer.
#
#   Returns:
#     True if (a, b, c) is a Pythagorean triple, False otherwise.
#   """
#
#   # Check if a^2 + b^2 = c^2.
#   return a**2 + b**2 == c**2
#
#
# def main():
#   # Get the input from the user.
#   a = int(input("Enter a: "))
#   b = int(input("Enter b: "))
#   c = int(input("Enter c: "))
#
#   # Check if (a, b, c) is a Pythagorean triple.
#   if pythagorean_triple(a, b, c):
#     print("(a, b, c) is a Pythagorean triple.")
#   else:
#     print("(a, b, c) is not a Pythagorean triple.")
#
#   # Check if a, b, and c are all prime numbers.
#   if is_prime(a) and is_prime(b) and is_prime(c):
#     print("a, b, and c are all prime numbers.")
#   else:
#     print("a, b, and c are not all prime numbers.")
#
#   # Check if c is a perfect square.
#   if is_perfect_square(c):
#     print("c is a perfect square.")
#   else:
#     print("c is not a perfect square.")
#
#
# if __name__ == "__main__":
#   main()
# ```
